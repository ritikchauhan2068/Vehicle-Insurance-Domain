# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://ritikchauhan2068:Wu1EHcmFrMpED3p5@cluster0.r6ehzrv.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# above, either remove your credentials or delete the mongoDB resource bofore pushing it to github.

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Uploading data to MongoDB
# ----> 2 rec = collection.insert_many(data)
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)
#     600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2061, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2047 """Execute an operation with consecutive retries if possible
#    2048
#    2049 Returns func()'s return value on success. On error retries the same
#    (...)
#    2058 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2059 """
#    2060 with self._tmp_session(session) as s:
# -> 2061     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:1947, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1942 # Ensure that the options supports retry_writes and there is a valid session not in
#    1943 # transaction, otherwise, we will not support retry behavior for this txn.
#    1944 retryable = bool(
#    1945     retryable and self.options.retry_writes and session and not session.in_transaction
#    1946 )
# -> 1947 return self._retry_internal(
#    1948     func=func,
#    1949     session=session,
#    1950     bulk=bulk,
#    1951     operation=operation,
#    1952     retryable=retryable,
#    1953     operation_id=operation_id,
#    1954 )
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:1993, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1956 @_csot.apply
#    1957 def _retry_internal(
#    1958     self,
#    (...)
#    1967     operation_id: Optional[int] = None,
#    1968 ) -> T:
#    1969     """Internal retryable helper for all client transactions.
#    1970
#    1971     :param func: Callback function we want to retry
#    (...)
#    1980     :return: Output of the calling func()
#    1981     """
#    1982     return _ClientConnectionRetryable(
#    1983         mongo_client=self,
#    1984         func=func,
#    1985         bulk=bulk,
#    1986         operation=operation,
#    1987         is_read=is_read,
#    1988         session=session,
#    1989         read_pref=read_pref,
#    1990         address=address,
#    1991         retryable=retryable,
#    1992         operation_id=operation_id,
# -> 1993     ).run()
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2730, in _ClientConnectionRetryable.run(self)
#    2728 self._check_last_error(check_csot=True)
#    2729 try:
# -> 2730     return self._read() if self._is_read else self._write()
#    2731 except ServerSelectionTimeoutError:
#    2732     # The application may think the write was never attempted
#    2733     # if we raise ServerSelectionTimeoutError on the retry
#    2734     # attempt. Raise the original exception instead.
#    2735     self._check_last_error()
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2862, in _ClientConnectionRetryable._write(self)
#    2854         if self._retrying:
#    2855             _debug_log(
#    2856                 _COMMAND_LOGGER,
#    2857                 message=f"Retrying write attempt number {self._attempt_number}",
#    (...)
#    2860                 operationId=self._operation_id,
#    2861             )
# -> 2862         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2863 except PyMongoError as exc:
#    2864     if not self._retryable:
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\bulk.py:593, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     590 def retryable_bulk(
#     591     session: Optional[ClientSession], conn: Connection, retryable: bool
#     592 ) -> None:
# --> 593     self._execute_command(
#     594         generator,
#     595         write_concern,
#     596         session,
#     597         conn,
#     598         op_id,
#     599         retryable,
#     600         full_result,
#     601     )
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\bulk.py:538, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     536 # Run as many ops as possible in one command.
#     537 if write_concern.acknowledged:
# --> 538     result, to_send = self._execute_batch(bwc, cmd, ops, client)
#     540     # Retryable writeConcernErrors halt the execution of this run.
#     541     wce = result.get("writeConcernError", {})
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\bulk.py:462, in _Bulk._execute_batch(self, bwc, cmd, ops, client)
#     460 else:
#     461     request_id, msg, to_send = bwc.batch_command(cmd, ops)
# --> 462     result = self.write_command(bwc, cmd, request_id, msg, to_send, client)  # type: ignore[arg-type]
#     464 return result, to_send
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\bulk.py:274, in _Bulk.write_command(self, bwc, cmd, request_id, msg, docs, client)
#     272     bwc._start(cmd, request_id, docs)
#     273 try:
# --> 274     reply = bwc.conn.write_command(request_id, msg, bwc.codec)  # type: ignore[misc]
#     275     duration = datetime.datetime.now() - bwc.start_time
#     276     if _COMMAND_LOGGER.isEnabledFor(logging.DEBUG):
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\pool.py:501, in Connection.write_command(self, request_id, msg, codec_options)
#     491 def write_command(
#     492     self, request_id: int, msg: bytes, codec_options: CodecOptions
#     493 ) -> dict[str, Any]:
#     494     """Send "insert" etc. command, returning response as a dict.
#     495
#     496     Can raise ConnectionFailure or OperationFailure.
#    (...)
#     499     :param msg: bytes, the command message.
#     500     """
# --> 501     self.send_message(msg, 0)
#     502     reply = self.receive_message(request_id)
#     503     result = reply.command_response(codec_options)
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\pool.py:459, in Connection.send_message(self, message, max_doc_size)
#     457 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     458 except BaseException as error:
# --> 459     self._raise_connection_failure(error)
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\pool.py:456, in Connection.send_message(self, message, max_doc_size)
#     450     raise DocumentTooLarge(
#     451         "BSON document too large (%d bytes) - the connected server "
#     452         "supports BSON document sizes up to %d bytes." % (max_doc_size, self.max_bson_size)
#     453     )
#     455 try:
# --> 456     sendall(self.conn.get_conn, message)
#     457 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     458 except BaseException as error:
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\site-packages\pymongo\network_layer.py:239, in sendall(sock, buf)
#     238 def sendall(sock: Union[socket.socket, _sslConn], buf: bytes) -> None:
# --> 239     sock.sendall(buf)
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\ssl.py:1270, in SSLSocket.sendall(self, data, flags)
#    1268         amount = len(byte_view)
#    1269         while count < amount:
# -> 1270             v = self.send(byte_view[count:])
#    1271             count += v
#    1272 else:
#
# File c:\Users\User 2\anaconda3\envs\vehicle\lib\ssl.py:1239, in SSLSocket.send(self, data, flags)
#    1235     if flags != 0:
#    1236         raise ValueError(
#    1237             "non-zero flags not allowed in calls to send() on %s" %
#    1238             self.__class__)
# -> 1239     return self._sslobj.write(data)
#    1240 else:
#    1241     return super().send(data, flags)
#
# KeyboardInterrupt:

# %%
# Load back data from mongodb

df = pd.DataFrame(list(collection.find()))
df.head(2)
# Out:
#                         _id  id Gender  Age  Driving_License  Region_Code  \
# 0  685d14a44f0fb4c34a90d47e   1   Male   44                1         28.0
# 1  685d14a44f0fb4c34a90d47f   2   Male   76                1          3.0
#
#    Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  \
# 0                   0   > 2 Years            Yes         40454.0
# 1                   0    1-2 Year             No         33536.0
#
#    Policy_Sales_Channel  Vintage  Response
# 0                  26.0      217         1
# 1                  26.0      183         0
